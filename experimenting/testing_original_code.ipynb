# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

from csst.csst_analyzer import CSSTA

# %%
path = Path('..') / 'tests' / 'test_data' / 'example_data.csv'

# %%
cssta1 = CSSTA(path)

# %%
cssta1.samples
# Out:
# {'Reactor1': '5.11 mg/ml PEG in MeOH',
#  'Reactor2': '5.19 mg/ml PEO in MeOH',
#  'Reactor3': '5.10 mg/ml PVP in MeOH'}

# %%
dir(cssta1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'df',
#  'header_data',
#  'plot_dat',
#  'samples']

# %%
cssta1.plot_dat
# Out:
# <bound method CSSTA.plot_dat of <csst.csst_analyzer.CSSTA object at 0x104a1a160>>

# %%
cssta1.header_data
# Out:
# {'Crystal16 Data Report File': ['Version: 1014', '', '', '', '', '', '', ''],
#  '': ['', '', '', '', '', '', '', ''],
#  'Experiment details': ['', '', '', '', '', '', '', ''],
#  'ExperimentNumber': ['0', '', '', '', '', '', '', ''],
#  'Experimentor': ['', '', '', '', '', '', '', ''],
#  'Project': ['MA-MeOH test(PEG-PEO-PVP)08192022', '', '', '', '', '', '', ''],
#  'Reactor1': ['5.11 mg/ml PEG in MeOH', '', '', '', '', '', '', ''],
#  'Reactor2': ['5.19 mg/ml PEO in MeOH', '', '', '', '', '', '', ''],
#  'Reactor3': ['5.10 mg/ml PVP in MeOH', '', '', '', '', '', '', ''],
#  'Reactor4': ['0 mg/ml  in ', '', '', '', '', '', '', ''],
#  'Labjournal': ['', '', '', '', '', '', '', ''],
#  'Description': ['', '', '', '', '', '', '', ''],
#  'Start of Experiment': ['8/19/22 13:54', '', '', '', '', '', '', ''],
#  'Temperature Program': ['', '', '', '', '', '', '', ''],
#  'Block': ['A', '', '', '', '', '', '', ''],
#  'Heat to': ['25', ' at ', '0.5', ' °C/min', '', '', '', ''],
# ...

# %%
fig = cssta1.plot_dat()

# %%
fig.show()
# Out:
# /var/folders/cx/3f096grx2yjg6gtx2hjv1r5h0000gn/T/ipykernel_64661/89474557.py:1: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
x = list(range(0,100))

# %%
y = [np.sin(i) + (0.5 - np.random.uniform()) for i in x]

# %%
plt.plot(x, y)

# %%
cssta1.df
# Out:
#            Date Time Decimal Time [mins]  Temperature Setpoint [°C]  \
# 0      8/19/22 13:54             0:00:00                       23.4
# 1      8/19/22 13:54             0:00:02                       23.0
# 2      8/19/22 13:54             0:00:03                       22.7
# 3      8/19/22 13:54             0:00:04                       22.4
# 4      8/19/22 13:54             0:00:05                       22.0
# ...              ...                 ...                        ...
# 32294   8/20/22 3:46            13:51:59                       25.0
# 32295   8/20/22 3:46            13:52:00                       25.0
# 32296   8/20/22 3:46            13:52:03                       25.0
# 32297   8/20/22 3:46            13:52:27                       25.0
# 32298   8/20/22 3:46            13:52:31                       25.0
#
#        Temperature Actual [°C]  Reactor1 Transmission [%]  \
# 0                         23.4                        100
# ...
